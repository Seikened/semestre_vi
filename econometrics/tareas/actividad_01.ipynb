# %%
# %pip install colorstreak
# Out:
# Requirement already satisfied: colorstreak in /usr/local/lib/python3.12/dist-packages (2.1.3)
# Requirement already satisfied: python-dotenv>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from colorstreak) (1.2.1)
# Requirement already satisfied: typer>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from colorstreak) (0.21.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.21.1->colorstreak) (8.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from typer>=0.21.1->colorstreak) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.21.1->colorstreak) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.21.1->colorstreak) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.21.1->colorstreak) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.21.1->colorstreak) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.21.1->colorstreak) (0.1.2)

# %%
from colorstreak import Logger as log
from matplotlib import pyplot as plt
import numpy as np

# %%
"""
Para los mínimos cuadrados ordinarios (MCO), se busca estimar los parámetros de un modelo lineal
Beta_1
formula = sum( (x_i - x_media) * (y_i - y) ) / sum( (x_i - x_media)**2 )

Beta_0
fomula = y_media - Beta_1 * x_media

"""

def betas(x, y):
    x_media = np.mean(x)
    y_media = np.mean(y)

    numerador = np.sum( (x - x_media) * (y - y_media) )
    denominador = np.sum( (x - x_media)**2 )

    beta_1 = numerador / denominador
    beta_0 = y_media - beta_1 * x_media

    return beta_0, beta_1


def error(x, y, beta_0, beta_1):
    y_pred = beta_0 + beta_1 * x
    residuals = y - y_pred
    mse = np.mean(residuals**2)
    return mse


def ecuacion_recta(beta_0, beta_1):
    return f"y = {beta_0:.2f} + {beta_1:.2f} * x"








# Datos de la Encuesta Nacional de Ingresos y Gastos de los Hogares (ENIGH)
hogares =   np.array([1, 2,  3,  4,  5])
ingreso_x = np.array([6, 8, 10, 12, 14])
consumo_y = np.array([4.9, 5.6, 6.3, 7.0, 7.6])




beta_0, beta_1 = betas(ingreso_x, consumo_y)
mse = error(ingreso_x, consumo_y, beta_0, beta_1)
recta_pred = ecuacion_recta(beta_0, beta_1)

log.info(f"Beta 0: {beta_0:.2f}, Beta 1: {beta_1:.2f}")
log.info(f"Mean Squared Error: {mse:.4f}")
log.info(f"Ecuación de la recta: {recta_pred}")




x_obj = 10
y_pred_10 = beta_0 + beta_1 * x_obj
residuo = 6.3 - y_pred_10

log.step(f"Para X=10: Real=6.3, Predicho={y_pred_10:.2f}, Residuo={residuo:.2f}")
# Out:
# [INFO] Beta 0: 2.88, Beta 1: 0.34
# [INFO] Mean Squared Error: 0.0008
# [INFO] Ecuación de la recta: y = 2.88 + 0.34 * x
# [STEP] Para X=10: Real=6.3, Predicho=6.28, Residuo=0.02

# %%
plt.scatter(ingreso_x, consumo_y, color='lightgreen', label='Datos Reales')
plt.plot(ingreso_x, beta_0 + beta_1 * ingreso_x, color='black', label='Línea de Regresión')
plt.xlabel('Ingreso (X)')
plt.ylabel('Consumo (Y)')
plt.title('Regresión Lineal por Mínimos Cuadrados Ordinarios')
plt.legend()
plt.show()
